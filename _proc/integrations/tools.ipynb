# %% [raw]
# ---
# output-file: tools.html
# title: Agent Tools
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(get_profile_url)
# Out:
# ---
#
# ### get_profile_url
#
# >      get_profile_url (text:str)
