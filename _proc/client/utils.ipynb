# %% [raw]
# ---
# description: supporting functions
# output-file: utils.html
# title: Utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
import re
import unicodedata

# %%
#| echo: false
#| output: asis
show_doc(strip_accents)
# Out:
# ---
#
# ### strip_accents
#
# >      strip_accents (text_str:str)

# %%
strip_accents("est être"), strip_accents("https://kožušček.com")
# Out:
# ('est etre', 'https://kozuscek.com')

# %%
#| echo: false
#| output: asis
show_doc(clean_file_name)
# Out:
# ---
#
# ### clean_file_name
#
# >      clean_file_name (file_name:str)

# %%
clean_file_name("est être"), clean_file_name("kožušček")
# Out:
# ('est_etre', 'kozuscek')
